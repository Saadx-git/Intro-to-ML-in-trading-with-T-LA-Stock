# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load and prepare dataset (same as before)
tesla_data = load_dataset('codesignal/tsla-historic-prices')
tesla_df = pd.DataFrame(tesla_data['train'])

tesla_df['Date'] = pd.to_datetime(tesla_df['Date'])
tesla_df.set_index('Date', inplace=True)
tesla_df.sort_index(inplace=True)

# TODO: Filter January 2020
tesla_jan_2020 = tesla_df.loc['2020-01']

# TODO: Filter Q1 2020 (Jan to March inclusive)
tesla_q1_2020 = tesla_df.loc['2020-01':'2020-03']

# TODO: Create a plot (figure size 10x5)
plt.figure(figsize=(10,5))

# TODO: Plot Close prices of Q1 2020
# Add marker='o', linestyle='-', and a label
plt.plot(tesla_q1_2020.index , tesla_q1_2020['Close'], color = 'blue', linestyle = '-', marker = 'o', label = 'Close Price')
# TODO: Add title, xlabel, ylabel
plt.title("2020-Q1 Close Prices")
plt.xlabel('Time')
plt.ylabel('Close Price')

# TODO: Add grid and legend
plt.grid(True)
plt.legend(['Close Prices'])
# TODO: Show plot
plt.show()
# Out:
# Using the latest cached version of the dataset since codesignal/tsla-historic-prices couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/saad/.cache/huggingface/datasets/codesignal___tsla-historic-prices/default/0.0.0/158577c50fe7e84eeaf9e3944ef4014c456d5e7f (last modified on Fri Dec  5 13:40:17 2025).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load and prepare dataset (same as before)
tesla_data = load_dataset('codesignal/tsla-historic-prices')
tesla_df = pd.DataFrame(tesla_data['train'])

tesla_df['Date'] = pd.to_datetime(tesla_df['Date'])
tesla_df.set_index('Date',inplace=True)
tesla_df.sort_index(inplace=True)

# TODO: Filter 2019 data
tesla_2019 = tesla_df.loc['2019']

# TODO: Filter 2020 data
tesla_2020 = tesla_df.loc['2020']

# TODO: Create figure (10,5)
plt.figure(figsize=(20,10))

# TODO: Plot 2019 Close prices
# Use different color and label
plt.plot(tesla_2019.index, tesla_2019['Close'], color = 'blue', label = '2019 Close Prices', linestyle = '-', linewidth = 2)

# TODO: Plot 2020 Close prices
# Use different color and label
plt.plot(tesla_2020.index, tesla_2020['Close'], color = 'green', label = '2020 Close Prices', linestyle = '-', linewidth = 2)

# TODO: Add title, labels
plt.title("2019-2020 Close Prices")
plt.xlabel('Time')
plt.ylabel('Close Price')

# TODO: Add grid and legend
plt.grid(True)
plt.legend()
# TODO: Show plot
plt.show()
# Out:
# Using the latest cached version of the dataset since codesignal/tsla-historic-prices couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/saad/.cache/huggingface/datasets/codesignal___tsla-historic-prices/default/0.0.0/158577c50fe7e84eeaf9e3944ef4014c456d5e7f (last modified on Fri Dec  5 13:40:17 2025).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load and prepare dataset (same as before)
tesla_data = load_dataset('codesignal/tsla-historic-prices')
tesla_df = pd.DataFrame(tesla_data['train'])

tesla_df['Date'] = pd.to_datetime(tesla_df['Date'])
tesla_df.set_index('Date', inplace=True)
tesla_df.sort_index(inplace=True)

tesla_march_2020 = tesla_df.loc['2020-03']

# TODO: Create a plot (figure size 10x5)
plt.figure(figsize=(10,5))

# TODO: Plot Close prices of Q1 2020
# Add marker='o', linestyle='-', and a label
plt.plot(tesla_march_2020.index , tesla_march_2020['Close'], color = 'red', linestyle = '-',linewidth = 2, label = 'March Close Price')
# TODO: Add title, xlabel, ylabel
plt.title("2020-March Close Prices")
plt.xlabel('Time')
plt.ylabel('Close Price')

# TODO: Add grid and legend
plt.grid(True)
plt.legend()
# TODO: Show plot
plt.show()
# Out:
# Using the latest cached version of the dataset since codesignal/tsla-historic-prices couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /home/saad/.cache/huggingface/datasets/codesignal___tsla-historic-prices/default/0.0.0/158577c50fe7e84eeaf9e3944ef4014c456d5e7f (last modified on Fri Dec  5 13:40:17 2025).
